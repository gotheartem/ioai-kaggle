# %%
import pandas as pd
import numpy as np
import datetime as dt
from catboost import CatBoostRegressor
from sklearn.metrics import mean_absolute_error
import tqdm
import optuna

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('data/raw/train.csv', parse_dates=['Date'])
sample_submission = pd.read_csv('data/raw/sample_submission.csv')

# %%
train['Date'] = pd.to_datetime(train['Date'].apply(lambda x: x[:-2] + '01'), format='%Y-%m-%d')
train['Month'] = train['Date'].dt.to_period('M').astype(str)

# %%
monthly_agg = (
    train
    .groupby(['Company_ID', 'Product_ID', 'Month'], as_index=False)
    .agg({'Target': 'sum'})
    .rename(columns={'Target': 'sum_sales'})
    .sort_values(by=['Company_ID', 'Product_ID', 'Month'])
)

# %%
d = {'Company_ID': [], 'Product_ID': [], 'Month': []}
ar = monthly_agg['Company_ID'].sort_values().unique()
br = monthly_agg['Product_ID'].sort_values().unique()
cr = monthly_agg['Month'].sort_values().unique()
for company_id in ar:
    for product_id in br:
        for month in cr:
            d['Company_ID'].append(company_id)
            d['Product_ID'].append(product_id)
            d['Month'].append(month)
d = pd.DataFrame(d)
monthly_agg = d.merge(monthly_agg, 'left', on=['Company_ID', 'Product_ID', 'Month']).fillna(0)

# %%
monthly_agg_saved = monthly_agg.copy()
monthly_agg
# Out:
#          Company_ID  Product_ID    Month  sum_sales
# 0                 0           0  2019-01        0.0
# 1                 0           0  2019-02        0.0
# 2                 0           0  2019-03        0.0
# 3                 0           0  2019-04        0.0
# 4                 0           0  2019-05        0.0
# ...             ...         ...      ...        ...
# 3459115           3       14668  2023-08        0.0
# 3459116           3       14668  2023-09        0.0
# 3459117           3       14668  2023-10        0.0
# 3459118           3       14668  2023-11        0.0
# 3459119           3       14668  2023-12        0.0
#
# [3459120 rows x 4 columns]

# %%
monthly_agg['Month_date'] = pd.to_datetime(monthly_agg['Month'], format='%Y-%m')

n_lags = 15

subset = []
gb = monthly_agg.groupby(['Company_ID','Product_ID'])
for i in range(n_lags + 1):
    monthly_agg[f'prev_sum_sales_{i}'] = gb['sum_sales'].shift(i)
    subset.append(f'prev_sum_sales_{i}')
    if i > 0:
        if i + 1 <= 9:
            feats_to_mean = [f'prev_sum_sales_{j}' for j in range(i + 1)]
            monthly_agg[f'rolling_sum_sales_{i + 1}'] = monthly_agg[feats_to_mean].mean(skipna=False, axis=1)
            subset.append(f'rolling_sum_sales_{i + 1}')
        monthly_agg[f'delta_sum_sales_{i}'] = monthly_agg['prev_sum_sales_0'] - monthly_agg[f'prev_sum_sales_{i}']
        subset.append(f'delta_sum_sales_{i}')

monthly_agg['target'] = gb['sum_sales'].shift(-1)

# %%
monthly_agg.dropna(subset=['target'], inplace=True)

# %%
monthly_agg
# Out:
#          Company_ID  Product_ID    Month  sum_sales Month_date  \
# 0                 0           0  2019-01        0.0 2019-01-01
# 1                 0           0  2019-02        0.0 2019-02-01
# 2                 0           0  2019-03        0.0 2019-03-01
# 3                 0           0  2019-04        0.0 2019-04-01
# 4                 0           0  2019-05        0.0 2019-05-01
# ...             ...         ...      ...        ...        ...
# 3459114           3       14668  2023-07        0.0 2023-07-01
# 3459115           3       14668  2023-08        0.0 2023-08-01
# 3459116           3       14668  2023-09        0.0 2023-09-01
# 3459117           3       14668  2023-10        0.0 2023-10-01
# 3459118           3       14668  2023-11        0.0 2023-11-01
#
#          prev_sum_sales_0  prev_sum_sales_1  rolling_sum_sales_2  \
# 0                     0.0               NaN                  NaN
# 1                     0.0               0.0                  0.0
# 2                     0.0               0.0                  0.0
# 3                     0.0               0.0                  0.0
# 4                     0.0               0.0                  0.0
# ...                   ...               ...                  ...
# 3459114               0.0               0.0                  0.0
# 3459115               0.0               0.0                  0.0
# 3459116               0.0               0.0                  0.0
# 3459117               0.0               0.0                  0.0
# 3459118               0.0               0.0                  0.0
#
#          delta_sum_sales_1  prev_sum_sales_2  ...  delta_sum_sales_11  \
# 0                      NaN               NaN  ...                 NaN
# 1                      0.0               NaN  ...                 NaN
# 2                      0.0               0.0  ...                 NaN
# 3                      0.0               0.0  ...                 NaN
# 4                      0.0               0.0  ...                 NaN
# ...                    ...               ...  ...                 ...
# 3459114                0.0               5.0  ...                 0.0
# 3459115                0.0               0.0  ...                 0.0
# 3459116                0.0               0.0  ...                 0.0
# 3459117                0.0               0.0  ...                 0.0
# 3459118                0.0               0.0  ...                 0.0
#
#          prev_sum_sales_12  delta_sum_sales_12  prev_sum_sales_13  \
# 0                      NaN                 NaN                NaN
# 1                      NaN                 NaN                NaN
# 2                      NaN                 NaN                NaN
# 3                      NaN                 NaN                NaN
# 4                      NaN                 NaN                NaN
# ...                    ...                 ...                ...
# 3459114                0.0                 0.0                0.0
# 3459115                0.0                 0.0                0.0
# 3459116                0.0                 0.0                0.0
# 3459117                0.0                 0.0                0.0
# 3459118                0.0                 0.0                0.0
#
#          delta_sum_sales_13  prev_sum_sales_14  delta_sum_sales_14  \
# 0                       NaN                NaN                 NaN
# 1                       NaN                NaN                 NaN
# 2                       NaN                NaN                 NaN
# 3                       NaN                NaN                 NaN
# 4                       NaN                NaN                 NaN
# ...                     ...                ...                 ...
# 3459114                 0.0                0.0                 0.0
# 3459115                 0.0                0.0                 0.0
# 3459116                 0.0                0.0                 0.0
# 3459117                 0.0                0.0                 0.0
# 3459118                 0.0                0.0                 0.0
#
#          prev_sum_sales_15  delta_sum_sales_15  target
# 0                      NaN                 NaN     0.0
# 1                      NaN                 NaN     0.0
# 2                      NaN                 NaN     0.0
# 3                      NaN                 NaN     0.0
# 4                      NaN                 NaN     0.0
# ...                    ...                 ...     ...
# 3459114                0.0                 0.0     0.0
# 3459115                0.0                 0.0     0.0
# 3459116                0.0                 0.0     0.0
# 3459117                0.0                 0.0     0.0
# 3459118                0.0                 0.0     0.0
#
# [3401468 rows x 45 columns]

# %%
def predict_next_month(df, model):
    df = df.copy()
    df['Month_date'] = pd.to_datetime(df['Month'], format='%Y-%m')
    df['Month_pred'] = (df['Month_date'] + pd.offsets.MonthBegin(1)).dt.to_period('M').astype(str)
    df = df.sort_values(by='Month_date')

    gb = df.groupby(['Company_ID', 'Product_ID'])
    for i in range(n_lags + 1):
        df[f'prev_sum_sales_{i}'] = gb['sum_sales'].shift(i)
        if i > 0:
            if i + 1 <= 9:
                feats_to_mean = [f'prev_sum_sales_{j}' for j in range(i + 1)]
                df[f'rolling_sum_sales_{i + 1}'] = df[feats_to_mean].mean(skipna=False, axis=1)
            df[f'delta_sum_sales_{i}'] = df['prev_sum_sales_0'] - df[f'prev_sum_sales_{i}']

    df['Target'] = gb['sum_sales'].shift(-1)

    to_predict = df['Target'].isna()
    df.loc[to_predict, 'Target'] = model.predict(df.loc[to_predict, feature_cols + cat_cols]).round()
    df.loc[to_predict, 'Target'] = df.loc[to_predict, 'Target'].apply(lambda x: max(x, 0))
    return df.loc[to_predict, ['Company_ID', 'Product_ID', 'Month_pred', 'Target']]

# %%
# Сортируем по Month_date (по возрастанию времени)
monthly_agg.sort_values(by=['Month_date'], inplace=True)

# Пример: берём валидацию на последние 3 месяца, которые у нас есть в данных
all_months = sorted(monthly_agg['Month_date'].unique())
N_valid_months = 3
valid_threshold = all_months[-N_valid_months]  # первая из последних 3
train_data = monthly_agg[monthly_agg['Month_date'] < valid_threshold].sample(frac=1, random_state=42)
valid_data = monthly_agg[monthly_agg['Month_date'] >= valid_threshold]

scale_factor = (monthly_agg_saved[monthly_agg_saved['Month'] == '2023-12']
                .groupby(['Company_ID', 'Product_ID'])['sum_sales']
                .agg(lambda x: int(x.sum() > 0)).sum() * 3) / len(sample_submission)

# %%
randids = np.random.choice(monthly_agg['Product_ID'].unique(), 3000)
tune_data = monthly_agg[monthly_agg['Product_ID'].isin(randids)]
tune_train = tune_data[tune_data['Month_date'] < valid_threshold].sample(frac=1, random_state=42)
tune_valid = tune_data[tune_data['Month_date'] >= valid_threshold]

feature_cols = subset
cat_cols = ['Company_ID', 'Product_ID']

X_train_tune = tune_train[tune_train['target'] != 0][feature_cols + cat_cols]
y_train_tune = tune_train[tune_train['target'] != 0]['target']

X_valid_tune = tune_valid[tune_valid['target'] != 0][feature_cols + cat_cols]
y_valid_tune = tune_valid[tune_valid['target'] != 0]['target']

cat_features_indices = [X_train_tune.columns.get_loc(c) for c in cat_cols]

mag = monthly_agg_saved[monthly_agg_saved['Product_ID'].isin(randids)].copy()
valid_saved = mag[mag['sum_sales'] != 0][pd.to_datetime(mag['Month'], format='%Y-%m') >= valid_threshold].copy()
mag_saved = mag[mag['sum_sales'] != 0][pd.to_datetime(mag['Month'], format='%Y-%m') < valid_threshold].copy()

def objective(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 1000, 1800),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.05, log=True),
        'depth': trial.suggest_int('depth', 4, 14),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.5, 1.0),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 0.1, 10),
        'cat_features': trial.suggest_categorical('cat_features', [cat_features_indices]),
        'loss_function': trial.suggest_categorical('loss_function', ['MAE']),
        'eval_metric': trial.suggest_categorical('eval_metric', ['MAE']),
        'random_seed': trial.suggest_categorical('random_seed', [42]),
        'verbose': 0
    }

    model = CatBoostRegressor(**params)

    model.fit(
        X_train_tune,
        y_train_tune,
        eval_set=(X_valid_tune, y_valid_tune),
        early_stopping_rounds=100
    )

    mag = mag_saved.copy()
    valid_data = valid_saved.copy()

    preds = []
    for i in range(N_valid_months):
        p = predict_next_month(mag, model)
        p.columns = ['Company_ID', 'Product_ID', 'Month', 'sum_sales']
        preds.append(p)
        mag = pd.concat([mag, p], axis=0)

    preds = pd.concat(preds, axis=0)
    merged = valid_data.merge(preds, on=['Company_ID', 'Product_ID', 'Month'], suffixes=('_actual', '_pred'))
    raw_mae = mean_absolute_error(merged['sum_sales_actual'], merged['sum_sales_pred'])

    return raw_mae * scale_factor

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

print("Лучшие найденные параметры:")
print(study.best_params)
# Out:
# [I 2025-02-03 20:36:55,224] A new study created in memory with name: no-name-3051029e-d416-400b-837b-70141c26376e
# [I 2025-02-03 20:37:28,720] Trial 0 finished with value: 12.096878883021214 and parameters: {'iterations': 1603, 'learning_rate': 0.035405191410459357, 'depth': 10, 'subsample': 0.7435675778029962, 'colsample_bylevel': 0.7622794644536715, 'l2_leaf_reg': 7.650134745917095, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 0 with value: 12.096878883021214.
# [I 2025-02-03 20:44:30,769] Trial 1 finished with value: 12.22308022737863 and parameters: {'iterations': 1689, 'learning_rate': 0.00721573182779872, 'depth': 14, 'subsample': 0.6556242916554862, 'colsample_bylevel': 0.616115499191513, 'l2_leaf_reg': 0.8980111971416116, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 0 with value: 12.096878883021214.
# [I 2025-02-03 20:45:11,052] Trial 2 finished with value: 13.65779589315035 and parameters: {'iterations': 1359, 'learning_rate': 0.01008474301325049, 'depth': 8, 'subsample': 0.8148000060307796, 'colsample_bylevel': 0.6896409992562118, 'l2_leaf_reg': 8.753148596381035, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 0 with value: 12.096878883021214.
# [I 2025-02-03 20:46:28,828] Trial 3 finished with value: 12.867280969867757 and parameters: {'iterations': 1321, 'learning_rate': 0.009712276562262433, 'depth': 11, 'subsample': 0.5624393743028688, 'colsample_bylevel': 0.9431837879449997, 'l2_leaf_reg': 5.395829540136915, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 0 with value: 12.096878883021214.
# [I 2025-02-03 20:48:35,873] Trial 4 finished with value: 13.443098068474306 and parameters: {'iterations': 1646, 'learning_rate': 0.005996219227009057, 'depth': 12, 'subsample': 0.7640391743347537, 'colsample_bylevel': 0.7224848523984475, 'l2_leaf_reg': 4.7459838100273295, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 0 with value: 12.096878883021214.
# [I 2025-02-03 20:52:23,929] Trial 5 finished with value: 12.492055893316767 and parameters: {'iterations': 1392, 'learning_rate': 0.020630495707551343, 'depth': 14, 'subsample': 0.7421176084848504, 'colsample_bylevel': 0.6630874149484003, 'l2_leaf_reg': 0.21164694392751196, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 0 with value: 12.096878883021214.
# [I 2025-02-03 20:52:48,068] Trial 6 finished with value: 14.408514217404813 and parameters: {'iterations': 1432, 'learning_rate': 0.007675317654733984, 'depth': 4, 'subsample': 0.8535419195830045, 'colsample_bylevel': 0.7239266870075969, 'l2_leaf_reg': 0.5287562147976703, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 0 with value: 12.096878883021214.
# [I 2025-02-03 20:53:39,532] Trial 7 finished with value: 12.07301165045043 and parameters: {'iterations': 1780, 'learning_rate': 0.015969864524552558, 'depth': 8, 'subsample': 0.6890758075059344, 'colsample_bylevel': 0.9934622757043708, 'l2_leaf_reg': 8.397090760771963, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 7 with value: 12.07301165045043.
# [I 2025-02-03 20:54:21,051] Trial 8 finished with value: 13.975310537687497 and parameters: {'iterations': 1202, 'learning_rate': 0.0065394724717034464, 'depth': 9, 'subsample': 0.6724510162936017, 'colsample_bylevel': 0.6195651906743616, 'l2_leaf_reg': 8.230094852150822, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 7 with value: 12.07301165045043.
# [I 2025-02-03 20:58:24,433] Trial 9 finished with value: 11.720366584938315 and parameters: {'iterations': 1453, 'learning_rate': 0.028078486290413405, 'depth': 14, 'subsample': 0.5509732543715807, 'colsample_bylevel': 0.5567119071155123, 'l2_leaf_reg': 9.148354056048804, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 9 with value: 11.720366584938315.
# [I 2025-02-03 20:58:41,504] Trial 10 finished with value: 12.644913450230764 and parameters: {'iterations': 1017, 'learning_rate': 0.04889620122782496, 'depth': 6, 'subsample': 0.5364081476815424, 'colsample_bylevel': 0.5034782603632075, 'l2_leaf_reg': 9.839351715157628, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 9 with value: 11.720366584938315.
# [I 2025-02-03 20:59:23,824] Trial 11 finished with value: 12.344776296374368 and parameters: {'iterations': 1775, 'learning_rate': 0.023317804629478574, 'depth': 7, 'subsample': 0.615977959261919, 'colsample_bylevel': 0.9823380427767229, 'l2_leaf_reg': 6.2385020900864285, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 9 with value: 11.720366584938315.
# [I 2025-02-03 21:01:43,457] Trial 12 finished with value: 11.769817345455756 and parameters: {'iterations': 1509, 'learning_rate': 0.014272697263532776, 'depth': 12, 'subsample': 0.9764045322777493, 'colsample_bylevel': 0.8558850556668394, 'l2_leaf_reg': 3.72892903642329, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 9 with value: 11.720366584938315.
# [I 2025-02-03 21:03:08,816] Trial 13 finished with value: 11.392983241989882 and parameters: {'iterations': 1538, 'learning_rate': 0.02901222726784966, 'depth': 12, 'subsample': 0.9978659721021726, 'colsample_bylevel': 0.8482803160266243, 'l2_leaf_reg': 2.896832628244373, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 13 with value: 11.392983241989882.
# [I 2025-02-03 21:05:01,155] Trial 14 finished with value: 11.813743780232095 and parameters: {'iterations': 1231, 'learning_rate': 0.035222286288909714, 'depth': 13, 'subsample': 0.972840183922014, 'colsample_bylevel': 0.8305240664533878, 'l2_leaf_reg': 2.7276880552406917, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 13 with value: 11.392983241989882.
# [I 2025-02-03 21:05:54,889] Trial 15 finished with value: 11.744394720200587 and parameters: {'iterations': 1513, 'learning_rate': 0.027178341922165346, 'depth': 12, 'subsample': 0.8854635557056241, 'colsample_bylevel': 0.5032476968284746, 'l2_leaf_reg': 3.0908747387602307, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 13 with value: 11.392983241989882.
# [I 2025-02-03 21:10:48,219] Trial 16 finished with value: 11.39233963122393 and parameters: {'iterations': 1544, 'learning_rate': 0.03399455767835486, 'depth': 14, 'subsample': 0.9290845678676182, 'colsample_bylevel': 0.8671228567748168, 'l2_leaf_reg': 1.8420239033901122, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 16 with value: 11.39233963122393.
# [I 2025-02-03 21:11:15,970] Trial 17 finished with value: 12.057457723606552 and parameters: {'iterations': 1567, 'learning_rate': 0.04591041018169511, 'depth': 10, 'subsample': 0.9172204781591351, 'colsample_bylevel': 0.8710575908409139, 'l2_leaf_reg': 1.6911571276147765, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 16 with value: 11.39233963122393.
# [I 2025-02-03 21:14:21,707] Trial 18 finished with value: 11.792236453803143 and parameters: {'iterations': 1714, 'learning_rate': 0.017787478999876073, 'depth': 13, 'subsample': 0.9308868272717019, 'colsample_bylevel': 0.8098198182582651, 'l2_leaf_reg': 2.6665496749881386, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 16 with value: 11.39233963122393.
# [I 2025-02-03 21:15:18,818] Trial 19 finished with value: 11.363967123291472 and parameters: {'iterations': 1551, 'learning_rate': 0.03576257381173396, 'depth': 11, 'subsample': 0.8313163024128398, 'colsample_bylevel': 0.9002557823015459, 'l2_leaf_reg': 1.7507165774464601, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:15:58,477] Trial 20 finished with value: 12.061855730507235 and parameters: {'iterations': 1247, 'learning_rate': 0.03910533320440537, 'depth': 11, 'subsample': 0.8225674013845161, 'colsample_bylevel': 0.9145109914878313, 'l2_leaf_reg': 1.603219265362378, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:17:58,944] Trial 21 finished with value: 11.877729417213988 and parameters: {'iterations': 1565, 'learning_rate': 0.029417102583243246, 'depth': 13, 'subsample': 0.9951494616467744, 'colsample_bylevel': 0.9037744508665668, 'l2_leaf_reg': 1.8488171530501007, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:18:46,876] Trial 22 finished with value: 11.481694259230496 and parameters: {'iterations': 1495, 'learning_rate': 0.0392752072787622, 'depth': 11, 'subsample': 0.9248820825859897, 'colsample_bylevel': 0.7643794427620816, 'l2_leaf_reg': 3.896843159398304, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:19:52,705] Trial 23 finished with value: 11.633264594612587 and parameters: {'iterations': 1625, 'learning_rate': 0.02289811510394777, 'depth': 10, 'subsample': 0.8798090329783056, 'colsample_bylevel': 0.8056596357396522, 'l2_leaf_reg': 2.345640827217815, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:22:00,814] Trial 24 finished with value: 11.678102811307358 and parameters: {'iterations': 1522, 'learning_rate': 0.031017701580778184, 'depth': 13, 'subsample': 0.9406552040119027, 'colsample_bylevel': 0.8886152953888447, 'l2_leaf_reg': 3.53119982682749, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:23:02,696] Trial 25 finished with value: 11.434764307546374 and parameters: {'iterations': 1690, 'learning_rate': 0.043502357427372004, 'depth': 12, 'subsample': 0.8080850619731188, 'colsample_bylevel': 0.9364247755243128, 'l2_leaf_reg': 4.368547907393126, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:24:00,322] Trial 26 finished with value: 11.704061778867489 and parameters: {'iterations': 1306, 'learning_rate': 0.024775411229358908, 'depth': 11, 'subsample': 0.8744830985253654, 'colsample_bylevel': 0.8385487207029673, 'l2_leaf_reg': 1.1031332305908763, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:31:31,862] Trial 27 finished with value: 12.018358369574864 and parameters: {'iterations': 1444, 'learning_rate': 0.019173814538240543, 'depth': 14, 'subsample': 0.9572376459423556, 'colsample_bylevel': 0.7911566863642621, 'l2_leaf_reg': 5.7424023312832695, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:32:33,931] Trial 28 finished with value: 12.187413464098695 and parameters: {'iterations': 1591, 'learning_rate': 0.013081968905313435, 'depth': 9, 'subsample': 0.9020490244015179, 'colsample_bylevel': 0.9531142874447782, 'l2_leaf_reg': 2.166396816378489, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:33:05,057] Trial 29 finished with value: 12.109429292957309 and parameters: {'iterations': 1132, 'learning_rate': 0.03471679907700272, 'depth': 10, 'subsample': 0.7775524323104885, 'colsample_bylevel': 0.7639228137264832, 'l2_leaf_reg': 6.877406265749482, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:34:44,527] Trial 30 finished with value: 11.887651749855774 and parameters: {'iterations': 1626, 'learning_rate': 0.03225271528528831, 'depth': 13, 'subsample': 0.858175347756688, 'colsample_bylevel': 0.8711002412777125, 'l2_leaf_reg': 1.161256713103082, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:35:56,464] Trial 31 finished with value: 11.400974742333807 and parameters: {'iterations': 1687, 'learning_rate': 0.03917110115527839, 'depth': 12, 'subsample': 0.8068154681462215, 'colsample_bylevel': 0.9236111540049302, 'l2_leaf_reg': 4.4985245349619705, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:36:57,699] Trial 32 finished with value: 12.062016633198722 and parameters: {'iterations': 1712, 'learning_rate': 0.03797123216084374, 'depth': 12, 'subsample': 0.7151761294704919, 'colsample_bylevel': 0.9103819354325986, 'l2_leaf_reg': 3.192401839125373, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:37:33,576] Trial 33 finished with value: 12.081861298482295 and parameters: {'iterations': 1558, 'learning_rate': 0.04389168093150689, 'depth': 11, 'subsample': 0.8297591101457278, 'colsample_bylevel': 0.9684360715848374, 'l2_leaf_reg': 3.8819649303377806, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:41:53,205] Trial 34 finished with value: 12.219218562782906 and parameters: {'iterations': 1672, 'learning_rate': 0.026715760325013094, 'depth': 14, 'subsample': 0.7881521606189144, 'colsample_bylevel': 0.9363339591983649, 'l2_leaf_reg': 4.548929397230818, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:42:21,470] Trial 35 finished with value: 12.016427537277004 and parameters: {'iterations': 1749, 'learning_rate': 0.049831753936896254, 'depth': 10, 'subsample': 0.9874917293687522, 'colsample_bylevel': 0.8437289956807941, 'l2_leaf_reg': 5.12313398268201, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:43:35,580] Trial 36 finished with value: 11.82463152902281 and parameters: {'iterations': 1362, 'learning_rate': 0.033113081455651484, 'depth': 12, 'subsample': 0.8432213245388006, 'colsample_bylevel': 0.8852178625590913, 'l2_leaf_reg': 2.8501508379321168, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:45:35,678] Trial 37 finished with value: 11.608431945892873 and parameters: {'iterations': 1653, 'learning_rate': 0.04003597776983981, 'depth': 13, 'subsample': 0.7414921662621528, 'colsample_bylevel': 0.9265011114483718, 'l2_leaf_reg': 1.264665000281512, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:47:02,593] Trial 38 finished with value: 12.81707933012337 and parameters: {'iterations': 1477, 'learning_rate': 0.009934360678452313, 'depth': 11, 'subsample': 0.9600738239405511, 'colsample_bylevel': 0.7846858755650252, 'l2_leaf_reg': 0.1532598585512761, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:56:13,331] Trial 39 finished with value: 11.413525152269903 and parameters: {'iterations': 1394, 'learning_rate': 0.021848650175503092, 'depth': 14, 'subsample': 0.792542031511899, 'colsample_bylevel': 0.9993307665091687, 'l2_leaf_reg': 2.224608064718133, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 21:56:52,550] Trial 40 finished with value: 12.121443360588444 and parameters: {'iterations': 1599, 'learning_rate': 0.025182352411878876, 'depth': 9, 'subsample': 0.7483252223089492, 'colsample_bylevel': 0.7392711693521058, 'l2_leaf_reg': 0.7644142178147764, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 19 with value: 11.363967123291472.
# [I 2025-02-03 22:04:06,849] Trial 41 finished with value: 10.97291994874412 and parameters: {'iterations': 1404, 'learning_rate': 0.030321210692265597, 'depth': 14, 'subsample': 0.8024825266288653, 'colsample_bylevel': 0.9680361445766793, 'l2_leaf_reg': 2.1695829855260658, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:07:59,614] Trial 42 finished with value: 12.213211528967339 and parameters: {'iterations': 1414, 'learning_rate': 0.03030258046633731, 'depth': 14, 'subsample': 0.6321070612300541, 'colsample_bylevel': 0.9538959515450934, 'l2_leaf_reg': 1.9714496704969149, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:10:02,947] Trial 43 finished with value: 11.65600550834295 and parameters: {'iterations': 1316, 'learning_rate': 0.036901362286360914, 'depth': 13, 'subsample': 0.7115354884013589, 'colsample_bylevel': 0.9696340858879463, 'l2_leaf_reg': 4.301468163338863, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:10:29,080] Trial 44 finished with value: 15.225470816322003 and parameters: {'iterations': 1469, 'learning_rate': 0.005160742493487082, 'depth': 4, 'subsample': 0.9045325271394489, 'colsample_bylevel': 0.9050764305126282, 'l2_leaf_reg': 3.3165548341995787, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:11:20,960] Trial 45 finished with value: 11.623395896201297 and parameters: {'iterations': 1539, 'learning_rate': 0.04277421112127441, 'depth': 12, 'subsample': 0.768869115919786, 'colsample_bylevel': 0.6966560221215372, 'l2_leaf_reg': 0.6233271544138035, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:19:14,829] Trial 46 finished with value: 12.4665796338311 and parameters: {'iterations': 1381, 'learning_rate': 0.008527047779986415, 'depth': 14, 'subsample': 0.5107985590315787, 'colsample_bylevel': 0.8614807282179429, 'l2_leaf_reg': 1.537630840318305, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:19:40,996] Trial 47 finished with value: 12.550249033405077 and parameters: {'iterations': 1749, 'learning_rate': 0.03436986010760243, 'depth': 8, 'subsample': 0.8085834102460665, 'colsample_bylevel': 0.8225147207546596, 'l2_leaf_reg': 2.5300721944462548, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:22:22,581] Trial 48 finished with value: 11.338115424192331 and parameters: {'iterations': 1601, 'learning_rate': 0.027209219336761917, 'depth': 13, 'subsample': 0.8582856404754476, 'colsample_bylevel': 0.8816055717750088, 'l2_leaf_reg': 4.883460068505215, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:25:38,586] Trial 49 finished with value: 11.532432241279844 and parameters: {'iterations': 1591, 'learning_rate': 0.020266111219926535, 'depth': 13, 'subsample': 0.8591162629054658, 'colsample_bylevel': 0.8885985994631015, 'l2_leaf_reg': 6.903867616467089, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:33:59,009] Trial 50 finished with value: 11.716504920342594 and parameters: {'iterations': 1426, 'learning_rate': 0.016939608977225944, 'depth': 14, 'subsample': 0.9044680762898354, 'colsample_bylevel': 0.8492273828879764, 'l2_leaf_reg': 5.91807427781159, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:34:30,109] Trial 51 finished with value: 12.728958289418213 and parameters: {'iterations': 1631, 'learning_rate': 0.02753891249574166, 'depth': 5, 'subsample': 0.8400103642727956, 'colsample_bylevel': 0.9266044756804982, 'l2_leaf_reg': 4.903201044241077, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:35:45,497] Trial 52 finished with value: 11.95453363528446 and parameters: {'iterations': 1556, 'learning_rate': 0.03107325841167069, 'depth': 12, 'subsample': 0.945872224216444, 'colsample_bylevel': 0.9745837836885184, 'l2_leaf_reg': 5.47122925803294, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:38:30,014] Trial 53 finished with value: 11.940481466894472 and parameters: {'iterations': 1491, 'learning_rate': 0.025104977849955384, 'depth': 13, 'subsample': 0.8123698882973945, 'colsample_bylevel': 0.880455312272039, 'l2_leaf_reg': 2.9659402782063267, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 41 with value: 10.97291994874412.
# [I 2025-02-03 22:40:58,922] Trial 54 finished with value: 10.917676691333098 and parameters: {'iterations': 1668, 'learning_rate': 0.028153280496855355, 'depth': 12, 'subsample': 0.8835510488789271, 'colsample_bylevel': 0.9520646709353786, 'l2_leaf_reg': 4.069350024709821, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 22:45:35,051] Trial 55 finished with value: 12.031820561429395 and parameters: {'iterations': 1538, 'learning_rate': 0.01186392094566161, 'depth': 13, 'subsample': 0.869786505937328, 'colsample_bylevel': 0.8992061199316426, 'l2_leaf_reg': 3.607947266862654, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 22:51:20,050] Trial 56 finished with value: 11.909266344745719 and parameters: {'iterations': 1651, 'learning_rate': 0.02917462481622313, 'depth': 14, 'subsample': 0.8905426689383451, 'colsample_bylevel': 0.9508794178500489, 'l2_leaf_reg': 2.6089528852896637, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 22:54:44,331] Trial 57 finished with value: 12.016588439968492 and parameters: {'iterations': 1582, 'learning_rate': 0.022763248390157646, 'depth': 13, 'subsample': 0.96933489468154, 'colsample_bylevel': 0.98229964149092, 'l2_leaf_reg': 4.164638836820531, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 22:56:32,108] Trial 58 finished with value: 11.45080094246472 and parameters: {'iterations': 1520, 'learning_rate': 0.026255185987892588, 'depth': 12, 'subsample': 0.998208640234296, 'colsample_bylevel': 0.644193448108975, 'l2_leaf_reg': 1.3836778911806906, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 22:58:16,193] Trial 59 finished with value: 11.249565309643208 and parameters: {'iterations': 1455, 'learning_rate': 0.01957681776685869, 'depth': 11, 'subsample': 0.9246057747525072, 'colsample_bylevel': 0.5667971968620418, 'l2_leaf_reg': 1.9099252959051043, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 22:59:26,113] Trial 60 finished with value: 11.408751705755748 and parameters: {'iterations': 1466, 'learning_rate': 0.01832001497833237, 'depth': 11, 'subsample': 0.9362351361689037, 'colsample_bylevel': 0.5278330901907619, 'l2_leaf_reg': 1.9372093120421048, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:00:39,703] Trial 61 finished with value: 11.297889751320229 and parameters: {'iterations': 1434, 'learning_rate': 0.02090954828673227, 'depth': 11, 'subsample': 0.9240002375775525, 'colsample_bylevel': 0.6108382807051346, 'l2_leaf_reg': 2.3081624245153076, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:01:29,336] Trial 62 finished with value: 12.552394402624923 and parameters: {'iterations': 1360, 'learning_rate': 0.014792353991157432, 'depth': 10, 'subsample': 0.919163939394972, 'colsample_bylevel': 0.5849044434615336, 'l2_leaf_reg': 2.3027524080821626, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:02:32,856] Trial 63 finished with value: 11.402583769248691 and parameters: {'iterations': 1334, 'learning_rate': 0.020778510325611982, 'depth': 11, 'subsample': 0.8960256770198012, 'colsample_bylevel': 0.5689745684931594, 'l2_leaf_reg': 0.4016232350698523, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:03:26,958] Trial 64 finished with value: 12.016802976890476 and parameters: {'iterations': 1440, 'learning_rate': 0.0164821606003164, 'depth': 10, 'subsample': 0.8675072763194321, 'colsample_bylevel': 0.6190415636649271, 'l2_leaf_reg': 0.9009714634248798, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:04:35,413] Trial 65 finished with value: 11.13655798598784 and parameters: {'iterations': 1504, 'learning_rate': 0.023779668327438483, 'depth': 11, 'subsample': 0.8389108467138565, 'colsample_bylevel': 0.5931532719604076, 'l2_leaf_reg': 1.843090405752335, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:05:26,931] Trial 66 finished with value: 12.060032166670364 and parameters: {'iterations': 1277, 'learning_rate': 0.023953686251400264, 'depth': 11, 'subsample': 0.8447661197152705, 'colsample_bylevel': 0.5870113006733164, 'l2_leaf_reg': 3.325802354676008, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:06:02,717] Trial 67 finished with value: 12.56119041642629 and parameters: {'iterations': 1502, 'learning_rate': 0.01946422882684189, 'depth': 7, 'subsample': 0.8265340206998242, 'colsample_bylevel': 0.5369154608863721, 'l2_leaf_reg': 1.638464433734006, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:07:06,265] Trial 68 finished with value: 11.518004633276382 and parameters: {'iterations': 1410, 'learning_rate': 0.02143914443716639, 'depth': 11, 'subsample': 0.8793700163755699, 'colsample_bylevel': 0.6614335155727219, 'l2_leaf_reg': 0.9810051471108754, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:07:40,106] Trial 69 finished with value: 11.999318217748735 and parameters: {'iterations': 1441, 'learning_rate': 0.0284239313912196, 'depth': 10, 'subsample': 0.8352930129694921, 'colsample_bylevel': 0.6008097300688809, 'l2_leaf_reg': 2.080731391576784, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:08:21,732] Trial 70 finished with value: 11.918223261238573 and parameters: {'iterations': 1171, 'learning_rate': 0.022922136321882686, 'depth': 9, 'subsample': 0.7946326465833622, 'colsample_bylevel': 0.6411764623434039, 'l2_leaf_reg': 2.509355935273061, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:09:14,944] Trial 71 finished with value: 11.690009610477501 and parameters: {'iterations': 1020, 'learning_rate': 0.03314155894191943, 'depth': 12, 'subsample': 0.909008370275746, 'colsample_bylevel': 0.5473501736373528, 'l2_leaf_reg': 1.8470147716784153, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:09:58,973] Trial 72 finished with value: 11.462815010095856 and parameters: {'iterations': 1612, 'learning_rate': 0.03654813122537296, 'depth': 11, 'subsample': 0.9259888775360016, 'colsample_bylevel': 0.5776588263619364, 'l2_leaf_reg': 1.4043389914684823, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:11:27,304] Trial 73 finished with value: 11.877085806448035 and parameters: {'iterations': 1486, 'learning_rate': 0.018266552527236992, 'depth': 12, 'subsample': 0.9474458488569844, 'colsample_bylevel': 0.6062304453954634, 'l2_leaf_reg': 5.288451843885551, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:16:28,657] Trial 74 finished with value: 11.719669339941866 and parameters: {'iterations': 1543, 'learning_rate': 0.026024787791969213, 'depth': 14, 'subsample': 0.8540538128861315, 'colsample_bylevel': 0.6875517992414159, 'l2_leaf_reg': 1.7025143657296617, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:17:07,216] Trial 75 finished with value: 11.831925784370284 and parameters: {'iterations': 1577, 'learning_rate': 0.032770653605338484, 'depth': 11, 'subsample': 0.8843223233537217, 'colsample_bylevel': 0.5244094775656397, 'l2_leaf_reg': 2.8579651253404257, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:19:33,274] Trial 76 finished with value: 11.181503471143605 and parameters: {'iterations': 1381, 'learning_rate': 0.030337200021499613, 'depth': 13, 'subsample': 0.9185582846129872, 'colsample_bylevel': 0.6324434136417767, 'l2_leaf_reg': 2.34145898472236, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:20:38,927] Trial 77 finished with value: 11.980760773997071 and parameters: {'iterations': 1376, 'learning_rate': 0.023988963752224108, 'depth': 12, 'subsample': 0.8637458114137601, 'colsample_bylevel': 0.5612920086299319, 'l2_leaf_reg': 2.417865196868191, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:22:30,444] Trial 78 finished with value: 11.677834640154877 and parameters: {'iterations': 1457, 'learning_rate': 0.027888466047957475, 'depth': 13, 'subsample': 0.9183999056458877, 'colsample_bylevel': 0.6344379969073575, 'l2_leaf_reg': 3.907629231820673, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:24:24,897] Trial 79 finished with value: 11.827205972086626 and parameters: {'iterations': 1338, 'learning_rate': 0.030386426940533617, 'depth': 13, 'subsample': 0.5867576322016503, 'colsample_bylevel': 0.5995110100949583, 'l2_leaf_reg': 4.676821641511421, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:26:14,384] Trial 80 finished with value: 11.80006705145558 and parameters: {'iterations': 1403, 'learning_rate': 0.01512791280872881, 'depth': 12, 'subsample': 0.849245862457434, 'colsample_bylevel': 0.6269738602986378, 'l2_leaf_reg': 1.1478573397077463, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:29:46,851] Trial 81 finished with value: 11.561180188825775 and parameters: {'iterations': 1512, 'learning_rate': 0.035325280428370784, 'depth': 14, 'subsample': 0.9613384062764889, 'colsample_bylevel': 0.6646342327750943, 'l2_leaf_reg': 2.1765363885265483, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:32:17,184] Trial 82 finished with value: 11.822110720189492 and parameters: {'iterations': 1286, 'learning_rate': 0.022044342448363546, 'depth': 13, 'subsample': 0.8916202287226352, 'colsample_bylevel': 0.9144560788804055, 'l2_leaf_reg': 3.098283030602602, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:38:16,694] Trial 83 finished with value: 11.43524701562084 and parameters: {'iterations': 1420, 'learning_rate': 0.03151110656601281, 'depth': 14, 'subsample': 0.9330306817823546, 'colsample_bylevel': 0.944479091944626, 'l2_leaf_reg': 1.906847253992555, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:38:58,153] Trial 84 finished with value: 12.09467987957087 and parameters: {'iterations': 1667, 'learning_rate': 0.04061269485672382, 'depth': 11, 'subsample': 0.9797446051816046, 'colsample_bylevel': 0.9902008099886486, 'l2_leaf_reg': 2.725015296105707, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:45:34,824] Trial 85 finished with value: 12.164404379215853 and parameters: {'iterations': 1619, 'learning_rate': 0.019606470404374188, 'depth': 14, 'subsample': 0.9063362845321169, 'colsample_bylevel': 0.9647471761635924, 'l2_leaf_reg': 1.6559242002817458, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:46:57,407] Trial 86 finished with value: 11.74101576367933 and parameters: {'iterations': 1455, 'learning_rate': 0.026001477716061438, 'depth': 12, 'subsample': 0.8778333235875951, 'colsample_bylevel': 0.8655073194972125, 'l2_leaf_reg': 1.3646595278124725, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:48:50,520] Trial 87 finished with value: 11.469680191599362 and parameters: {'iterations': 1707, 'learning_rate': 0.029579523075378877, 'depth': 13, 'subsample': 0.8214992551552357, 'colsample_bylevel': 0.7078398736429762, 'l2_leaf_reg': 9.28526226850849, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:50:11,914] Trial 88 finished with value: 11.612454513180085 and parameters: {'iterations': 1384, 'learning_rate': 0.046600925067598976, 'depth': 13, 'subsample': 0.7788036146434216, 'colsample_bylevel': 0.8196724473525425, 'l2_leaf_reg': 3.42702665417993, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:51:08,517] Trial 89 finished with value: 11.14170687211547 and parameters: {'iterations': 1529, 'learning_rate': 0.03433880986490005, 'depth': 10, 'subsample': 0.7982320447217403, 'colsample_bylevel': 0.934062218317852, 'l2_leaf_reg': 0.4198602955095798, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:52:11,241] Trial 90 finished with value: 11.446349301333541 and parameters: {'iterations': 1524, 'learning_rate': 0.024482320333140104, 'depth': 10, 'subsample': 0.7976712681002438, 'colsample_bylevel': 0.9314768326118406, 'l2_leaf_reg': 0.8343893361280283, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:52:49,704] Trial 91 finished with value: 11.880947471043756 and parameters: {'iterations': 1562, 'learning_rate': 0.034382791302542764, 'depth': 10, 'subsample': 0.8317782384141195, 'colsample_bylevel': 0.8948036142432138, 'l2_leaf_reg': 0.37207756286936444, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:53:34,466] Trial 92 finished with value: 11.493064716095677 and parameters: {'iterations': 1489, 'learning_rate': 0.03742744113610953, 'depth': 9, 'subsample': 0.9488666574435312, 'colsample_bylevel': 0.9535139379348707, 'l2_leaf_reg': 0.6593984858631332, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:54:35,997] Trial 93 finished with value: 11.538385640864917 and parameters: {'iterations': 1472, 'learning_rate': 0.027971523025344527, 'depth': 11, 'subsample': 0.8190064969800661, 'colsample_bylevel': 0.9180984709527014, 'l2_leaf_reg': 2.2699612775152884, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:55:12,834] Trial 94 finished with value: 12.09441170841839 and parameters: {'iterations': 1600, 'learning_rate': 0.04113027716416719, 'depth': 11, 'subsample': 0.7692884059422357, 'colsample_bylevel': 0.9623137889011295, 'l2_leaf_reg': 4.129616084031458, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:55:41,342] Trial 95 finished with value: 12.14332612663087 and parameters: {'iterations': 1633, 'learning_rate': 0.03158744172678764, 'depth': 10, 'subsample': 0.7295346600462258, 'colsample_bylevel': 0.6130363820494853, 'l2_leaf_reg': 2.0540880227849865, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:56:54,331] Trial 96 finished with value: 11.872097823011893 and parameters: {'iterations': 1547, 'learning_rate': 0.03335215555393899, 'depth': 12, 'subsample': 0.8530831059354929, 'colsample_bylevel': 0.9369203837136909, 'l2_leaf_reg': 1.0532465249499698, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:57:52,445] Trial 97 finished with value: 11.883843719490548 and parameters: {'iterations': 1529, 'learning_rate': 0.02678217572080477, 'depth': 11, 'subsample': 0.9155194309228458, 'colsample_bylevel': 0.9822699140993505, 'l2_leaf_reg': 4.9432490070283865, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-03 23:59:19,994] Trial 98 finished with value: 11.582258441410758 and parameters: {'iterations': 1432, 'learning_rate': 0.029079475537201083, 'depth': 12, 'subsample': 0.8930899032624368, 'colsample_bylevel': 0.8755340384359311, 'l2_leaf_reg': 1.5059928730568317, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# [I 2025-02-04 00:06:38,405] Trial 99 finished with value: 11.37303130824532 and parameters: {'iterations': 1570, 'learning_rate': 0.02067585399934569, 'depth': 14, 'subsample': 0.7809072392776567, 'colsample_bylevel': 0.7416797042207071, 'l2_leaf_reg': 6.481558624753492, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}. Best is trial 54 with value: 10.917676691333098.
# Лучшие найденные параметры:
# {'iterations': 1668, 'learning_rate': 0.028153280496855355, 'depth': 12, 'subsample': 0.8835510488789271, 'colsample_bylevel': 0.9520646709353786, 'l2_leaf_reg': 4.069350024709821, 'cat_features': [39, 40], 'loss_function': 'MAE', 'eval_metric': 'MAE', 'random_seed': 42}

# %%
cb_params = study.best_params
cb_params = {
    'iterations': 1668,
    'learning_rate': 0.028153280496855355,
    'depth': 12,
    'subsample': 0.8835510488789271,
    'colsample_bylevel': 0.9520646709353786,
    'l2_leaf_reg': 4.069350024709821,
    'cat_features': [39, 40],
    'loss_function': 'MAE',
    'eval_metric': 'MAE',
    'random_seed': 42
}
cb_params
# Out:
# {'iterations': 1668,
#  'learning_rate': 0.028153280496855355,
#  'depth': 12,
#  'subsample': 0.8835510488789271,
#  'colsample_bylevel': 0.9520646709353786,
#  'l2_leaf_reg': 4.069350024709821,
#  'cat_features': [39, 40],
#  'loss_function': 'MAE',
#  'eval_metric': 'MAE',
#  'random_seed': 42}

# %%
feature_cols = subset
cat_cols = ['Company_ID', 'Product_ID']

X_train = train_data[train_data['target'] != 0][feature_cols + cat_cols]
y_train = train_data[train_data['target'] != 0]['target']

X_valid = valid_data[valid_data['target'] != 0][feature_cols + cat_cols]
y_valid = valid_data[valid_data['target'] != 0]['target']

# Укажем, какие столбцы считать категориальными для CatBoost
# (CatBoost умеет работать с ними напрямую, выучивая таргет-кодирование)
cat_features_indices = [X_train.columns.get_loc(c) for c in cat_cols]  # индексы категориальных фич

# %%
X_train
# Out:
#          prev_sum_sales_0  prev_sum_sales_1  rolling_sum_sales_2  \
# 29490                 0.0               2.0                  1.0
# 1229635               1.0               1.0                  1.0
# 1560952               3.0               3.0                  3.0
# 1724800               1.0               1.0                  1.0
# 3174609               1.0               0.0                  0.5
# ...                   ...               ...                  ...
# 2970545               3.0               2.0                  2.5
# 2099764               7.0               6.0                  6.5
# 1385092               1.0               0.0                  0.5
# 2595552               7.0               3.0                  5.0
# 800568                0.0               0.0                  0.0
#
#          delta_sum_sales_1  prev_sum_sales_2  rolling_sum_sales_3  \
# 29490                 -2.0               0.0             0.666667
# 1229635                0.0               0.0             0.666667
# 1560952                0.0               2.0             2.666667
# 1724800                0.0               0.0             0.666667
# 3174609                1.0               0.0             0.333333
# ...                    ...               ...                  ...
# 2970545                1.0               1.0             2.000000
# 2099764                1.0              25.0            12.666667
# 1385092                1.0               0.0             0.333333
# 2595552                4.0               0.0             3.333333
# 800568                 0.0               0.0             0.000000
#
#          delta_sum_sales_2  prev_sum_sales_3  rolling_sum_sales_4  \
# 29490                  0.0               0.0                 0.50
# 1229635                1.0               2.0                 1.00
# 1560952                1.0               2.0                 2.50
# 1724800                1.0               0.0                 0.50
# 3174609                1.0               1.0                 0.50
# ...                    ...               ...                  ...
# 2970545                2.0               0.0                 1.50
# 2099764              -18.0              18.0                14.00
# 1385092                1.0               0.0                 0.25
# 2595552                7.0               7.0                 4.25
# 800568                 0.0               0.0                 0.00
#
#          delta_sum_sales_3  ...  prev_sum_sales_12  delta_sum_sales_12  \
# 29490                  0.0  ...                2.0                -2.0
# 1229635               -1.0  ...                0.0                 1.0
# 1560952                1.0  ...                0.0                 3.0
# 1724800                1.0  ...                0.0                 1.0
# 3174609                0.0  ...                NaN                 NaN
# ...                    ...  ...                ...                 ...
# 2970545                3.0  ...                NaN                 NaN
# 2099764              -11.0  ...                NaN                 NaN
# 1385092                1.0  ...                0.0                 1.0
# 2595552                0.0  ...                3.0                 4.0
# 800568                 0.0  ...               48.0               -48.0
#
#          prev_sum_sales_13  delta_sum_sales_13  prev_sum_sales_14  \
# 29490                  6.0                -6.0                3.0
# 1229635                2.0                -1.0                0.0
# 1560952                0.0                 3.0                0.0
# 1724800                2.0                -1.0                1.0
# 3174609                NaN                 NaN                NaN
# ...                    ...                 ...                ...
# 2970545                NaN                 NaN                NaN
# 2099764                NaN                 NaN                NaN
# 1385092                0.0                 1.0              125.0
# 2595552                NaN                 NaN                NaN
# 800568                47.0               -47.0                0.0
#
#          delta_sum_sales_14  prev_sum_sales_15  delta_sum_sales_15  \
# 29490                  -3.0                0.0                 0.0
# 1229635                 1.0                2.0                -1.0
# 1560952                 3.0                2.0                 1.0
# 1724800                 0.0                0.0                 1.0
# 3174609                 NaN                NaN                 NaN
# ...                     ...                ...                 ...
# 2970545                 NaN                NaN                 NaN
# 2099764                 NaN                NaN                 NaN
# 1385092              -124.0                2.0                -1.0
# 2595552                 NaN                NaN                 NaN
# 800568                  0.0                0.0                 0.0
#
#          Company_ID  Product_ID
# 29490             0         499
# 1229635           1        6182
# 1560952           1       11802
# 1724800           1       14588
# 3174609           3        9840
# ...             ...         ...
# 2970545           3        6375
# 2099764           2        6274
# 1385092           1        8828
# 2595552           3          21
# 800568            0       13577
#
# [801532 rows x 41 columns]

# %%
model = CatBoostRegressor(**cb_params, verbose=100)

model.fit(
    X_train,
    y_train,
    eval_set=(X_valid, y_valid),
    early_stopping_rounds=100
)
# Out:
# 0:	learn: 43.5551200	test: 48.2706738	best: 48.2706738 (0)	total: 581ms	remaining: 16m 8s
# 100:	learn: 23.8281971	test: 28.1906329	best: 28.1906329 (100)	total: 35.1s	remaining: 9m 5s
# 200:	learn: 21.9938100	test: 25.7978374	best: 25.7978374 (200)	total: 1m 6s	remaining: 8m 8s
# 300:	learn: 21.5213751	test: 25.2003152	best: 25.2003152 (300)	total: 1m 39s	remaining: 7m 30s
# 400:	learn: 21.3687896	test: 25.0557608	best: 25.0557608 (400)	total: 2m 13s	remaining: 7m 2s
# 500:	learn: 21.1773561	test: 24.8895871	best: 24.8895871 (500)	total: 2m 46s	remaining: 6m 26s
# 600:	learn: 20.5455543	test: 24.2485588	best: 24.2452404 (597)	total: 3m 14s	remaining: 5m 45s
# 700:	learn: 20.1381180	test: 24.0674396	best: 24.0667661 (698)	total: 3m 41s	remaining: 5m 4s
# 800:	learn: 19.5450196	test: 23.8708566	best: 23.8708566 (800)	total: 4m 9s	remaining: 4m 30s
# 900:	learn: 18.9912225	test: 23.7901672	best: 23.7774966 (890)	total: 4m 38s	remaining: 3m 57s
# 1000:	learn: 18.2206122	test: 23.6669993	best: 23.6669993 (1000)	total: 5m 6s	remaining: 3m 24s
# 1100:	learn: 17.5520504	test: 23.5801655	best: 23.5776410 (1098)	total: 5m 35s	remaining: 2m 52s
# 1200:	learn: 17.0094383	test: 23.5585681	best: 23.5573984 (1179)	total: 6m 3s	remaining: 2m 21s
# 1300:	learn: 16.2829960	test: 23.5351108	best: 23.5260604 (1285)	total: 6m 33s	remaining: 1m 50s
# 1400:	learn: 15.5875221	test: 23.5288847	best: 23.5224205 (1340)	total: 7m 2s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 23.52242055
# bestIteration = 1340
#
# Shrink model to first 1341 iterations.

# %%
y_pred_valid = model.predict(X_valid).round()
mae_valid = mean_absolute_error(y_valid, y_pred_valid)
print("Raw MAE (valid):    ", mae_valid)
print("Scaled MAE (valid): ", mae_valid * scale_factor)
# Out:
# Raw MAE (valid):     23.513392763940793
# Scaled MAE (valid):  9.58453272708063

# %%
mag = monthly_agg_saved[monthly_agg_saved['sum_sales'] != 0][pd.to_datetime(monthly_agg_saved['Month'], format='%Y-%m') < valid_threshold].copy()
preds = []
for i in range(N_valid_months):
    p = predict_next_month(mag, model)
    p.columns = ['Company_ID', 'Product_ID', 'Month', 'sum_sales']
    preds.append(p)
    mag = pd.concat([mag, p], axis=0)

preds = pd.concat(preds, axis=0)
valid_data = monthly_agg_saved[monthly_agg_saved['sum_sales'] != 0][pd.to_datetime(monthly_agg_saved['Month'], format='%Y-%m') >= valid_threshold].copy()
merged = valid_data.merge(preds, on=['Company_ID', 'Product_ID', 'Month'], suffixes=('_actual', '_pred'))
raw_mae = mean_absolute_error(merged['sum_sales_actual'], merged['sum_sales_pred'])
print("Рекурсивный прогноз - raw MAE (valid):    ", raw_mae)
print("Рекурсивный прогноз - scaled MAE (valid): ", raw_mae * scale_factor)
# Out:
# Рекурсивный прогноз - raw MAE (valid):     27.221712381440657
# Рекурсивный прогноз - scaled MAE (valid):  11.096118532380032

# %%
full_train = monthly_agg.dropna(subset=['target']).sample(frac=1, random_state=42)
X_full = full_train[full_train['target'] != 0][feature_cols + cat_cols]
y_full = full_train[full_train['target'] != 0]['target']

final_model = CatBoostRegressor(**cb_params, verbose=100)

final_model.fit(
    X_full,
    y_full
)
# Out:
# 0:	learn: 43.8930536	total: 435ms	remaining: 12m 5s
# 100:	learn: 24.0225650	total: 36.7s	remaining: 9m 29s
# 200:	learn: 22.1550106	total: 1m 9s	remaining: 8m 28s
# 300:	learn: 21.7281256	total: 1m 43s	remaining: 7m 51s
# 400:	learn: 21.5870249	total: 2m 14s	remaining: 7m 4s
# 500:	learn: 21.4904733	total: 2m 45s	remaining: 6m 24s
# 600:	learn: 20.2740573	total: 3m 16s	remaining: 5m 48s
# 700:	learn: 19.5676879	total: 3m 46s	remaining: 5m 12s
# 800:	learn: 18.8215251	total: 4m 16s	remaining: 4m 37s
# 900:	learn: 18.3008141	total: 4m 45s	remaining: 4m 3s
# 1000:	learn: 17.5675474	total: 5m 14s	remaining: 3m 29s
# 1100:	learn: 17.0164253	total: 5m 43s	remaining: 2m 57s
# 1200:	learn: 16.5967550	total: 6m 12s	remaining: 2m 24s
# 1300:	learn: 16.2058216	total: 6m 41s	remaining: 1m 53s
# 1400:	learn: 15.7450479	total: 7m 10s	remaining: 1m 22s
# 1500:	learn: 15.3417928	total: 7m 38s	remaining: 51s
# 1600:	learn: 15.1850093	total: 8m 3s	remaining: 20.2s
# 1667:	learn: 15.0546227	total: 8m 19s	remaining: 0us

# %%
sample_submission['Company_ID'] = sample_submission['Id'].apply(lambda x: x.split('_')[0]).astype(int)
sample_submission['Product_ID'] = sample_submission['Id'].apply(lambda x: x.split('_')[1]).astype(int)
sample_submission['Month_pred'] = sample_submission['Id'].apply(lambda x: x.split('_')[2]).astype(str)
sample_submission
# Out:
#                      Id  Target  Company_ID  Product_ID Month_pred
# 0           0_1_2024-01       0           0           1    2024-01
# 1           0_2_2024-01       0           0           2    2024-01
# 2           0_3_2024-01       0           0           3    2024-01
# 3           0_5_2024-01       0           0           5    2024-01
# 4           0_6_2024-01       0           0           6    2024-01
# ...                 ...     ...         ...         ...        ...
# 113851  3_14664_2024-03       0           3       14664    2024-03
# 113852  3_14665_2024-03       0           3       14665    2024-03
# 113853  3_14666_2024-03       0           3       14666    2024-03
# 113854  3_14667_2024-03       0           3       14667    2024-03
# 113855  3_14668_2024-03       0           3       14668    2024-03
#
# [113856 rows x 5 columns]

# %%
preds = []
mag = monthly_agg_saved.copy()
for i in range(3):
    p = predict_next_month(mag, final_model)
    preds.append(p.copy())
    p.columns = ['Company_ID', 'Product_ID', 'Month', 'sum_sales']
    mag = pd.concat([mag, p], axis=0)
preds = pd.concat(preds, axis=0)
sample_submission = sample_submission.drop(columns=['Target'], axis=1).merge(preds, 'left', on=['Company_ID', 'Product_ID', 'Month_pred'])

# %%
to_mult = monthly_agg_saved[monthly_agg_saved['Month'] == '2023-12'].groupby(['Company_ID', 'Product_ID'])['sum_sales'].agg(lambda x: int(x.sum() > 0)).reset_index()
for i in tqdm.tqdm(to_mult.index):
    sample_submission.loc[(sample_submission['Company_ID'] == to_mult.loc[i, 'Company_ID']) &
                          (sample_submission['Product_ID'] == to_mult.loc[i, 'Product_ID']), 'Target'] *= to_mult.loc[i, 'sum_sales']
# Out:
# 100%|██████████| 57652/57652 [00:33<00:00, 1698.47it/s]

# %%
sample_submission[['Id', 'Target']]
# Out:
#                      Id  Target
# 0           0_1_2024-01     6.0
# 1           0_2_2024-01     0.0
# 2           0_3_2024-01     0.0
# 3           0_5_2024-01     2.0
# 4           0_6_2024-01     3.0
# ...                 ...     ...
# 113851  3_14664_2024-03     0.0
# 113852  3_14665_2024-03   199.0
# 113853  3_14666_2024-03     0.0
# 113854  3_14667_2024-03     2.0
# 113855  3_14668_2024-03     0.0
#
# [113856 rows x 2 columns]

# %%
sample_submission[['Id', 'Target']].to_csv('data/submissions/bruh.csv', index=False)
